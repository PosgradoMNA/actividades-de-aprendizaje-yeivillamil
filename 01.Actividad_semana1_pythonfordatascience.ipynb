# %% [markdown]
# # **Python for data science - Yeison Villamil**

# %% [markdown]
# A continuación se presenta una serie de ejercicios por módulo que son encontrados en el curso **Python for data science** de **IBM**. Es un resumen del módulo 1-3 con preguntas sobre cada sesión y los quiz. A continuación se presenta una imagen con el avance del curso, mostrando mi usuario ***A01793803*** (Yeison Villamil)

# %%
from PIL import Image
from IPython.display import Image

# %%
progress = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/images/Progress_YeisonVillamil.png", width=600, height=300)
progress

# %% [markdown]
# # **Módulo 1**

# %%
print('Hello python')
# Out:
# Hello python

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %%
# print('Hello World!')
# Its a comment

# %% [markdown]
# ## 1. Types

# %%
type("Hello World")
# Out:
# str

# %%
type("1.1")
# Out:
# str

# %%
bool(int("1")), bool(1)
# Out:
# (True, True)

# %%
int(1.0)
# Out:
# 1

# %% [markdown]
# ## 2. Expressions and variables

# %% [markdown]
# Operands and operators

# %%
my_variable = 1

# %% [markdown]
# ## 3. String operation

# %%
name = "Michael Jackson"
name[::2]
# Out:
# 'McalJcsn'

# %%
name[0:5:2]
# Out:
# 'Mca'

# %%
print("Michael Jackson \nis the best")
# Out:
# Michael Jackson
# is the best

# %%
name.upper()
# Out:
# 'MICHAEL JACKSON'

# %%
Numbers = "0123456"
Numbers[::2]
# Out:
# '0246'

# %%
Numbers[::6]
# Out:
# '06'

# %%
"0123456".find('1')
# Out:
# 1

# %%
Letters="ABCDEFGHIJK"
Letters[0:4]
# Out:
# 'ABCD'

# %%
Good="GsoAo+d"
Good[::2]
# Out:
# 'Good'

# %%
"uppercase"
"uppercase".upper()
# Out:
# 'UPPERCASE'

# %% [markdown]
# ### QUIZ

# %%
3 + 2 * 2
# Out:
# 7

# %%
name = 'Lizz'
name[0:2]
# Out:
# 'Li'

# %%
var = '01234567'
var[::2]
# Out:
# '0246'

# %%
'1'+'2'
# Out:
# '12'

# %%
myvar = 'hello'
myvar.upper()
# Out:
# 'HELLO'

# %% [markdown]
# # **Módulo 2**

# %% [markdown]
# ## 1. Tuples

# %%
NT = (1, 2, ("pop", "rock"), (3, 4), ("disco", (1,2))) #Nesting

# %%
NT[3:5]
# Out:
# ((3, 4), ('disco', (1, 2)))

# %%
nt = ("New_member", 1)
NT_1 = NT + nt

# %% [markdown]
# ## 2. List

# %%
L = ["Michael Jackson", 10.1, 1982]

# %%
L.extend(["exit", 1])

# %%
L
# Out:
# ['Michael Jackson', 10.1, 1982, 'exit', 1]

# %% [markdown]
# ### Questions

# %%
# 1 Question
A=(0,1,2,3)
A[-1], A[3]
# Out:
# (3, 3)

# %%
# 2 Question
B=["a","b","c"]
B[1:]
# Out:
# ['b', 'c']

# %% [markdown]
# ---

# %%
A = (0,1,2,3)
A[0:2]
# Out:
# (0, 1)

# %%
B[0] = B[0].upper()
B
# Out:
# ['A', 'b', 'c']

# %% [markdown]
# ## 3. Sets

# %%
album_list = ["Michael Jackson", "Thriller", "Thriller", 1982]
album_set = set(album_list)
album_set
# Out:
# {1982, 'Michael Jackson', 'Thriller'}

# %%
album_set.add("NSYNC")
album_set
# Out:
# {1982, 'Michael Jackson', 'NSYNC', 'Thriller'}

# %%
album_set.remove("NSYNC")

# %%
album_set
# Out:
# {1982, 'Michael Jackson', 'Thriller'}

# %%
"Michael Jackson" in album_set
# Out:
# True

# %%
album_set2 = {"AC/DC", "Back in Black", "Michael Jackson"}
album_set3 = album_set & album_set2
album_set3
# Out:
# {'Michael Jackson'}

# %%
album_set.union(album_set2)
# Out:
# {1982, 'AC/DC', 'Back in Black', 'Michael Jackson', 'Thriller'}

# %% [markdown]
# ### Questions

# %%
S={'A','B','C'}
U={'A','Z','C'}
U.union(S)
# Out:
# {'A', 'B', 'C', 'Z'}

# %%
S={'A','B','C'}
U={'A','Z','C'}
S & U
# Out:
# {'A', 'C'}

# %% [markdown]
# ## 4. Dictionaries

# %% [markdown]
# ### Questions

# %%
D = {'a':0,'b':1,'c':2}
D.values()
# Out:
# dict_values([0, 1, 2])

# %%
D['b']
# Out:
# 1

# %% [markdown]
# ## Quiz

# %%
# 1
A = ('a','b','c')
A[0]
# Out:
# 'a'

# %%
L = ['a', 'b', 'c']
L.append(['a', 'b'])
L
# Out:
# ['a', 'b', 'c', ['a', 'b']]

# %%
# q3 = Image.open("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/question3.png")
q3 = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/question3.png", width=600, height=300)
q3

# %%
Dict={"A":1,"B":"2","C":[3,3,3],"D":(4,4,4),'E':5,'F':6}
Dict['D']
# Out:
# (4, 4, 4)

# %%
q5 = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/question5.png", width=600, height=300)
q5

# %% [markdown]
# # **Módulo 3**

# %% [markdown]
# ## 1. Conditions and branching

# %%
i= 1
i!=0
# Out:
# True

# %%
x = 'a'
if(x=='a'):
    print("this is a")
else:
    print("this is  not a")
# Out:
# this is a

# %%
y= 5
x=1
x>0 and y<10
# Out:
# True

# %% [markdown]
# ### Questions

# %%
i!=0 # 1, -1, 100000000
# Out:
# True

# %%
x='a'
if(x!='a'):
    print("This is not a.")
else:
    print("This is a.")
# Out:
# This is a.

# %% [markdown]
# ## 2. Loops

# %%
A=[3,4,5]
for a in A:
    print(a)
# Out:
# 3
# 4
# 5

# %%
x=3
y=1
while(y!=x):
    print(y)
    y=y+1
# Out:
# 1
# 2

# %%
range(3)
# Out:
# range(0, 3)

# %%
dates = [1982,1980,1973]
N = len(dates)

for i in range(N):
    print(dates[i])
# Out:
# 1982
# 1980
# 1973

# %% [markdown]
# ## 3. Functions

# %%
def f(a,b):
    return a*b

# %%
a=4
b=2

if a*b==f(a,b):   
    print("Correct.")   
else:    
    print("Incorrect.")
# Out:
# Correct.

# %%
def g(c):
    return sum(c)

# %%
c=[1,2,3,4,5]

if sum(c)==g(c):   
    print("Correct.")   
else:    
    print("Incorrect.")
# Out:
# Correct.

# %% [markdown]
# ### Questions

# %%
a=1
def add(b):
    return a+b

c=add(10)
c
# Out:
# 11

# %%
def f(*x):
    return sum(x)

c = 1
f(c)
# Out:
# 1

# %% [markdown]
# ## 4. Objects and classes

# %%
class Car(object):
    def __init__(self,make,model,color):
        self.make=make;
        self.model=model;
        self.color=color;
        self.owner_number=0 
    def car_info(self):
        print("make: ",self.make)
        print("model:", self.model)
        print("color:",self.color)
        print("number of owners:",self.owner_number)
    def sell(self):
        self.owner_number=self.owner_number+1

# %%
make="BMW"
model="M3"
color="red"
my_car = Car(make,model,color)

# %%
my_car.car_info()
# Out:
# make:  BMW
# model: M3
# color: red
# number of owners: 0

# %%
for i in range(5):
    my_car.sell()

my_car.car_info()
# Out:
# make:  BMW
# model: M3
# color: red
# number of owners: 5

# %% [markdown]
# ### Questions

# %%
make="Honda"
model="Accord"
color="blue"

# %%
my_car = Car(make="Honda",model="Accord",color="blue")
my_car.car_info()
# Out:
# make:  Honda
# model: Accord
# color: blue
# number of owners: 0

# %%
my_car = Car("Honda","Accord","blue")
my_car.car_info()
# Out:
# make:  Honda
# model: Accord
# color: blue
# number of owners: 0

# %%
my_car = Car(model="Accord",make="Honda",color="blue")
my_car.car_info()
# Out:
# make:  Honda
# model: Accord
# color: blue
# number of owners: 0

# %%
my_car = Car("Accord","Honda","blue")
my_car.car_info()
# Out:
# make:  Accord
# model: Honda
# color: blue
# number of owners: 0

# %% [markdown]
# ### Examples

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a class Circle

class Circle(object):
    
    # Constructor
    def __init__(self, radius=3, color='blue'):
        self.radius = radius
        self.color = color 
    
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return(self.radius)
    
    # Method
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()

# %%
# Create an object RedCircle

RedCircle = Circle(10, 'red')

# %%
# Find out the methods can be used on the object RedCircle

dir(RedCircle)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_radius',
#  'color',
#  'drawCircle',
#  'radius']

# %%
# Print the object attribute radius

RedCircle.radius
# Out:
# 10

# %%
# Print the object attribute color

RedCircle.color
# Out:
# 'red'

# %%
# Set the object attribute radius

RedCircle.radius = 1
RedCircle.radius
# Out:
# 1

# %% [markdown]
# ## Quiz

# %%
#1
x = 1
if (x!=1):
    print('Hello')
else:
    print('Hi')
print('Mike')
# Out:
# Hi
# Mike

# %%
#2
A = ['1','2','3']
for a in A:
    print(2*a)
# Out:
# 11
# 22
# 33

# %%
def Delta(x):
    if x==0:
        y=1
    else:
        y=0
    return(y)

# %%
Delta(0)
# Out:
# 1

# %%
B = [1,5,8,3,4]
B.sort()
B
# Out:
# [1, 3, 4, 5, 8]

# %%
B = [1,5,8,3,4]
sorted(B)
# Out:
# [1, 3, 4, 5, 8]
