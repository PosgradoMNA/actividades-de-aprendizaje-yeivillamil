# %% [markdown]
# # Actividad Semana 2 - Yeison Fernando Villamil Franco A01793803

# %% [markdown]
# ## Modulo 4

# %% [markdown]
# A continuación se presenta un resumen de los apuntes que se recogen del módulo 4. Adicionalmente en la imagen se muestra la terminación del módulo (progreso del curso)

# %%
progress = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/images/semana2/progress_semana2.png", width=600, height=300)
progress

# %% [markdown]
# ### Reading files with open

# %%
from pyodide.http import pyfetch
import pandas as pd

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt"

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())


download(filename, "Example1.txt")
# Out:
# <coroutine object download at 0x7f02e7fba640>

# %%
file_1 = open("Example1.txt", 'r')

# %%
file_1.name
# Out:
# 'Example1.txt'

# %%
file_1.mode
# Out:
# 'r'

# %%
contenido = file_1.read()
contenido
# Out:
# ''

# %%
file_1.readline()
# Out:
# ''

# %%
with open('file.txt' "r") as file_1:
    
    file = file_1.read()
    print(file)
    print(file_1.closed)
    print(file)

# %%
with open("Example1.txt", 'r') as file_1:
    
    file = file_1.readline()
    print(file)

# %% [markdown]
# ### Writing files with open

# %%
download(filename, "Example2.txt")
# Out:
# <coroutine object download at 0x7f02e7fba740>

# %%
file = "Example2.txt"
with open(file, "w") as file_1:
    
    file_1.write('Esta es la linea A')

# %%
with open(file, 'r') as file_1_write:
    print(file_1_write.read())
# Out:
# Esta es la linea A

# %%
lines = ["Esta es la linea A\n", "Esta es la linea B\n"]

with open(file, 'w') as file_1:
    for line in lines:
        file_1.write(line)

# %%
with open(file, 'r') as file_1_write:
    print(file_1_write.read())
# Out:
# Esta es la linea A
# Esta es la linea B

# %%
download(filename, "Example3.txt")
# Out:
# <coroutine object download at 0x7f02e7fba340>

# %% [markdown]
# #### Agregando las líneas de un text a otro

# %%
file1 = "Example2.txt"
file2 = "Example3.txt"

with open(file1, 'r') as file1_read:
    with open(file2, 'w') as file2_write:
        for line in file1_read:
            file2_write.write(line)

# %%
with open(file2, 'r') as file_write:
    print(file_write.read())
# Out:
# Esta es la linea A
# Esta es la linea B

# %% [markdown]
# ### Loading data with pandas

# %%
import pandas as pd
from pyodide.http import pyfetch
import pandas as pd

csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df[['Length']].head()
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33

# %%
df_1 = df[['Artist','Length','Genre']]
df_1.head()
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock

# %%
df.iloc[1,0] #Extrae la segunda fila de la primera columna
# Out:
# 'AC/DC'

# %%
df.loc[1, 'Released'] #Extrae la segunda fila de columns 'Released'
# Out:
# 1980

# %% [markdown]
# ### Quiz dataframe

# %%
q = df[['Rating']] #Selecciona en un datarrame solo la variable 'Rating'
q.head()
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0

# %%
q = df[['Released', 'Artist']] ## Extrae en dataframe las dos variables 'Released' y 'Artist'
q.head()
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# a  Michael Jackson                   Thriller      1982  0:42:19
# b            AC/DC              Back in Black      1980  0:42:11
# c       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# d  Whitney Houston              The Bodyguard      1992  0:57:44
# e        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# a               pop, rock, R&B                              46.0
# b                    hard rock                              26.1
# c             progressive rock                              24.2
# d               R&B, soul, pop                              27.4
# e  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# a                        65  30-Nov-82        NaN    10.0
# b                        50  25-Jul-80        NaN     9.5
# ...

# %%
new_index=['a','b','c','d','e','f','g','h'] # los índices del dataframe son numéricos y con esto cambian a letras del alfabeto
df.index = new_index

# %%
df[['Released', 'Artist']].head()
# Out:
#    Released           Artist
# a      1982  Michael Jackson
# b      1980            AC/DC
# c      1973       Pink Floyd
# d      1992  Whitney Houston
# e      1977        Meat Loaf

# %%
from PIL import Image
from IPython.display import Image

## Cargue de imágenes

# %%
q1 = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/images/semana2/Question1_pandas.png", width=600, height=300)
q1

# %%
import pandas as banana
df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})
df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
q2 = Image("/home/yvillamil/Documents/TEC/1. Trimestre/Ciencia y analítica de datos/images/semana2/question2_pandas.png", width=600, height=300)
q2

# %% [markdown]
# ### Working with and Saving Data with Pandas

# %%
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})
df.head()
# Out:
#    a  b
# 0  1  1
# 1  2  1
# 2  1  1

# %%
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool
